# %% [markdown]
# <center><h1>House Price Prediction (Regression)</h1></center>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://www.bankrate.com/2022/09/13091209/tips-for-selling-your-home.jpg?auto=webp&optimize=high&crop=16:9" alt="Home Selling Tips">
# </div>

# %% [markdown]
# Data on houses for sale in Istanbul and Izmir, listed on the website emlaksitem.com, was collected using web scraping. The collected data includes various features such as price, location, number of rooms, and square footage of the properties. The data was processed through a data preprocessing stage and subsequently used in a regression model to predict the price column.

# %%
import pandas as pd

# %%
df=pd.read_csv('emlak_sitem.csv')

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Aidat (TL) Banyo Sayısı Bina Yaşı  \
# 0             0         0.0        NaN          : 1   : 26-30
# 1             1         1.0        NaN          : 1   : 21-25
# 2             2         2.0     : 1702          : 1    : 5-10
# 3             3         3.0        NaN          : 2       : 4
# 4             4         4.0        NaN          : 1   : 16-20
#
#   Bir Kattaki Daire   Bulunduğu Kat   Eşyalı Gör. Arama İle Gez.  \
# 0               NaN             : 3      NaN                 NaN
# 1               NaN    : Giriş Katı      NaN                 NaN
# 2               NaN             : 7  : Hayır              : Evet
# 3               : 2             : 5  : Hayır             : Hayır
# 4               : 2  : Yüksek Giriş  : Hayır             : Hayır
#
#                    Isıtma  ... Metre Karesi (Net) Oda Sayısı         Price  \
# 0      : Doğalgaz (Kombi)  ...             : 95m2      : 2+1  2.600.000 TL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1123 entries, 0 to 1122
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           1123 non-null   int64
#  1   Unnamed: 0             423 non-null    float64
#  2   Aidat (TL)             262 non-null    object
#  3   Banyo Sayısı           1117 non-null   object
#  4   Bina Yaşı              1117 non-null   object
#  5   Bir Kattaki Daire      633 non-null    object
#  6   Bulunduğu Kat          1117 non-null   object
#  7   Eşyalı                 709 non-null    object
#  8   Gör. Arama İle Gez.    572 non-null    object
#  9   Isıtma                 1117 non-null   object
#  10  Kat Sayısı             1117 non-null   object
#  11  Krediye Uygun          1108 non-null   object
#  12  Kullanım Durumu        1117 non-null   object
#  13  Kısıtlama              1117 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1               0
# Unnamed: 0               700
# Aidat (TL)               861
# Banyo Sayısı               6
# Bina Yaşı                  6
# Bir Kattaki Daire        490
# Bulunduğu Kat              6
# Eşyalı                   414
# Gör. Arama İle Gez.      551
# Isıtma                     6
# Kat Sayısı                 6
# Krediye Uygun             15
# Kullanım Durumu            6
# Kısıtlama                  6
# Metre Karesi (Net)         1
# Oda Sayısı                 6
# Price                      1
# Site İçerisinde          414
# Takaslı                    6
# Yapı Kullanım İzin D.    516
# İlan No                    1
# İlan Tarihi                1
# İlan Türü                  1
# Şehir                      0
# dtype: int64

# %%
df=df.drop(['Aidat (TL)',"Unnamed: 0.1","Unnamed: 0","Bir Kattaki Daire","Gör. Arama İle Gez.","Yapı Kullanım İzin D."],axis=1)

# %%
df.head()
# Out:
#   Banyo Sayısı Bina Yaşı   Bulunduğu Kat   Eşyalı                  Isıtma  \
# 0          : 1   : 26-30             : 3      NaN      : Doğalgaz (Kombi)
# 1          : 1   : 21-25    : Giriş Katı      NaN  : Kalorifer (Doğalgaz)
# 2          : 1    : 5-10             : 7  : Hayır      : Doğalgaz (Kombi)
# 3          : 2       : 4             : 5  : Hayır      : Doğalgaz (Kombi)
# 4          : 1   : 16-20  : Yüksek Giriş  : Hayır      : Doğalgaz (Kombi)
#
#   Kat Sayısı Krediye Uygun Kullanım Durumu Kısıtlama Metre Karesi (Net)  \
# 0        : 3       : Hayır           : Boş     : Yok             : 95m2
# 1        : 6       : Hayır   : Mülk Sahibi     : Yok             : 75m2
# 2       : 12        : Evet   : Mülk Sahibi     : Yok             : 82m2
# 3        : 5        : Evet           : Boş     : Yok            : 180m2
# 4        : 5        : Evet           : Boş     : Yok             : 75m2
#
#   Oda Sayısı         Price Site İçerisinde  Takaslı     İlan No  \
# ...

# %%
df = df.applymap(lambda x: x[2:] if isinstance(x, str) and x.startswith(': ') else x)#The ': ' has been removed from all data
# Out:
# <ipython-input-8-17144193a2da>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x[2:] if isinstance(x, str) and x.startswith(': ') else x)#The ': ' has been removed from all data

# %%
df.head()
# Out:
#   Banyo Sayısı Bina Yaşı Bulunduğu Kat Eşyalı                Isıtma  \
# 0            1     26-30             3    NaN      Doğalgaz (Kombi)
# 1            1     21-25    Giriş Katı    NaN  Kalorifer (Doğalgaz)
# 2            1      5-10             7  Hayır      Doğalgaz (Kombi)
# 3            2         4             5  Hayır      Doğalgaz (Kombi)
# 4            1     16-20  Yüksek Giriş  Hayır      Doğalgaz (Kombi)
#
#   Kat Sayısı Krediye Uygun Kullanım Durumu Kısıtlama Metre Karesi (Net)  \
# 0          3         Hayır             Boş       Yok               95m2
# 1          6         Hayır     Mülk Sahibi       Yok               75m2
# 2         12          Evet     Mülk Sahibi       Yok               82m2
# 3          5          Evet             Boş       Yok              180m2
# 4          5          Evet             Boş       Yok               75m2
#
#   Oda Sayısı         Price Site İçerisinde Takaslı   İlan No   İlan Tarihi  \
# ...

# %%
df["Banyo Sayısı"].value_counts()
# Out:
# Banyo Sayısı
# 1     714
# 2     362
# 3      28
# 4       7
# 5       3
# 6+      3
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1123, 18)

# %%
import numpy as np

# %%
df = df[~df['Banyo Sayısı'].isnull()]

# %%
df.isnull().sum()
# Out:
# Banyo Sayısı            0
# Bina Yaşı               0
# Bulunduğu Kat           0
# Eşyalı                408
# Isıtma                  0
# Kat Sayısı              0
# Krediye Uygun           9
# Kullanım Durumu         0
# Kısıtlama               0
# Metre Karesi (Net)      0
# Oda Sayısı              0
# Price                   0
# Site İçerisinde       408
# Takaslı                 0
# İlan No                 0
# İlan Tarihi             0
# İlan Türü               0
# Şehir                   0
# dtype: int64

# %%
df['Banyo Sayısı'] = df['Banyo Sayısı'].replace('6+','6').astype(int)
# Out:
# <ipython-input-15-ed904eee56d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Banyo Sayısı'] = df['Banyo Sayısı'].replace('6+','6').astype(int)

# %%
df['Bina Yaşı']=df['Bina Yaşı'].replace("5-10","7")
df['Bina Yaşı']=df['Bina Yaşı'].replace("11-15","13")
df['Bina Yaşı']=df['Bina Yaşı'].replace("16-20","18")
df['Bina Yaşı']=df['Bina Yaşı'].replace("21-25","23")
df['Bina Yaşı']=df['Bina Yaşı'].replace("26-30","28")
df['Bina Yaşı']=df['Bina Yaşı'].replace("30+","45")
# Out:
# <ipython-input-16-217076c4d0f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bina Yaşı']=df['Bina Yaşı'].replace("5-10","7")
# <ipython-input-16-217076c4d0f2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bina Yaşı']=df['Bina Yaşı'].replace("11-15","13")
# <ipython-input-16-217076c4d0f2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['Bina Yaşı']=df['Bina Yaşı'].astype(int)
# Out:
# <ipython-input-17-d45c730cc1ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bina Yaşı']=df['Bina Yaşı'].astype(int)

# %%
df['Bulunduğu Kat']=df['Bulunduğu Kat'].replace(["Bahçe Katı","Giriş Katı","Zemin Kat","Müstakil"],"0")
df['Bulunduğu Kat']=df['Bulunduğu Kat'].replace("Kot 1",'-1')
df['Bulunduğu Kat']=df['Bulunduğu Kat'].replace("Kot 2",'-2')
df['Bulunduğu Kat']=df['Bulunduğu Kat'].replace("Kot 3",'-3')
df['Bulunduğu Kat']=df['Bulunduğu Kat'].replace("Kot 4",'-4')
df['Bulunduğu Kat']=df['Bulunduğu Kat'].replace(["Bodrum Kat","Çatı Katı",""],'-1')
df['Bulunduğu Kat']=df['Bulunduğu Kat'].replace("Yüksek Giriş",'1')
df['Bulunduğu Kat']=df['Bulunduğu Kat'].replace("Villa Tipi",'7')
# Out:
# <ipython-input-18-448bf9c277ff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bulunduğu Kat']=df['Bulunduğu Kat'].replace(["Bahçe Katı","Giriş Katı","Zemin Kat","Müstakil"],"0")
# <ipython-input-18-448bf9c277ff>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bulunduğu Kat']=df['Bulunduğu Kat'].replace("Kot 1",'-1')
# <ipython-input-18-448bf9c277ff>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df['Bulunduğu Kat'].value_counts()
# Out:
# Bulunduğu Kat
# 1         223
# 2         200
# 3         164
# 4         137
# 0         136
# 5          70
# -1         37
# 6          26
# 11         25
# 7          24
# 8          16
# 9          14
# 10         13
# 16          8
# -2          6
# 13          4
# -3          3
# -4          3
# 12          1
# 14          1
# 27          1
# 15          1
# 17          1
# 18          1
# 21          1
# Komple      1
# Name: count, dtype: int64

# %%
df=df[df['Bulunduğu Kat']!='Komple']

# %%
df['Eşyalı'].fillna('Hayır', inplace=True)
# Out:
# <ipython-input-21-2855ab3bd36f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Eşyalı'].fillna('Hayır', inplace=True)

# %%
df['Isıtma'].value_counts()
# Out:
# Isıtma
# Doğalgaz (Kombi)              693
# Klima                         109
# Merkezi Sistem (Pay Ölçer)     81
# Yok                            72
# Merkezi Sistem                 52
# Soba                           42
# Yerden Isıtma                  18
# Kalorifer (Doğalgaz)           11
# Jeotermal                      11
# Doğalgaz Sobası                 9
# Kalorifer (Kömür)               6
# Kombi (Elektrikli)              4
# Fan-Coil                        3
# Kat Kaloriferi                  3
# Güneş Enerjisi                  1
# Isı Pompası                     1
# Name: count, dtype: int64

# %%
replacements = {
    "Doğalgaz (Kombi)": "Doğalgaz",
    "Kalorifer (Doğalgaz)": "Doğalgaz",
    "Doğalgaz Sobası": "Doğalgaz",
    "Merkezi Sistem (Pay Ölçer)": "Merkezi Sistem",
    "Merkezi Sistem": "Merkezi Sistem",
    "Soba": "Soba",
    "Yerden Isıtma": "Yerden Isıtma",
    "Kalorifer (Kömür)": "Kalorifer",
    "Fan-Coil": "Kalorifer",
    "Kat Kaloriferi": "Kalorifer",
    "Kombi (Elektrikli)": "Kombi",
    "Jeotermal": "Jeotermal",
    "Güneş Enerjisi": "Güneş Enerjisi",
    "Isı Pompası": "Isı Pompası",
    "Yok": "Yok",
    "Klima": "Klima"
}
df['Isıtma'] = df['Isıtma'].replace(replacements)

# %%
df['Isıtma'].value_counts()
# Out:
# Isıtma
# Doğalgaz          713
# Merkezi Sistem    133
# Klima             109
# Yok                72
# Soba               42
# Yerden Isıtma      18
# Kalorifer          12
# Jeotermal          11
# Kombi               4
# Güneş Enerjisi      1
# Isı Pompası         1
# Name: count, dtype: int64

# %%
df=df[df['Isıtma']!='Güneş Enerjisi']

# %%
df=df[df['Isıtma']!='Isı Pompası']

# %%
df['Site İçerisinde'].fillna('Hayır', inplace=True)

# %%
df.head()
# Out:
#    Banyo Sayısı  Bina Yaşı Bulunduğu Kat Eşyalı    Isıtma Kat Sayısı  \
# 0             1         28             3  Hayır  Doğalgaz          3
# 1             1         23             0  Hayır  Doğalgaz          6
# 2             1          7             7  Hayır  Doğalgaz         12
# 3             2          4             5  Hayır  Doğalgaz          5
# 4             1         18             1  Hayır  Doğalgaz          5
#
#   Krediye Uygun Kullanım Durumu Kısıtlama Metre Karesi (Net) Oda Sayısı  \
# 0         Hayır             Boş       Yok               95m2        2+1
# 1         Hayır     Mülk Sahibi       Yok               75m2        2+1
# 2          Evet     Mülk Sahibi       Yok               82m2        2+1
# 3          Evet             Boş       Yok              180m2        4+2
# 4          Evet             Boş       Yok               75m2        1+1
#
#           Price Site İçerisinde Takaslı   İlan No   İlan Tarihi  \
# ...

# %%
df['Kat Sayısı'].value_counts()
# Out:
# Kat Sayısı
# 4      289
# 5      274
# 3      169
# 6       80
# 2       56
# 15      48
# 8       41
# 7       35
# 10      23
# 9       23
# 20      14
# 17      13
# 30+      9
# 16       8
# 25       8
# 1        7
# 19       4
# 29       4
# 11       3
# 14       3
# 13       2
# 12       1
# Name: count, dtype: int64

# %%
df['Kat Sayısı'] = df['Kat Sayısı'].replace("30+","30").astype(int)

# %%
df['Metre Karesi (Net)'].value_counts()
# Out:
# Metre Karesi (Net)
# 110m2    101
# 100m2     82
# 90m2      70
# 80m2      68
# 120m2     63
#         ...
# 152m2      1
# 174m2      1
# 48m2       1
# 187m2      1
# 176m2      1
# Name: count, Length: 124, dtype: int64

# %%
df['Metre Karesi (Net)'] = df['Metre Karesi (Net)'].str.replace("m2","").astype(int)

# %%
df['Oda Sayısı'].value_counts()
# Out:
# Oda Sayısı
# 3+1             478
# 2+1             422
# 1+1              95
# 4+1              63
# 4+2              18
# 5+1              12
# 5+2               7
# Stüdyo (1+0)      7
# 3+2               4
# 6+2               2
# 7+2               2
# 5+0               1
# 2+0               1
# 2+2               1
# 6+1               1
# Name: count, dtype: int64

# %%
df['Oda Sayısı'] = df['Oda Sayısı'].str.replace("Stüdyo (1+0)","1")

# %%
df['Oda Sayısı'] = df['Oda Sayısı'].apply(lambda x: str(eval(x))).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1114 entries, 0 to 1122
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Banyo Sayısı        1114 non-null   int64
#  1   Bina Yaşı           1114 non-null   int64
#  2   Bulunduğu Kat       1114 non-null   object
#  3   Eşyalı              1114 non-null   object
#  4   Isıtma              1114 non-null   object
#  5   Kat Sayısı          1114 non-null   int64
#  6   Krediye Uygun       1105 non-null   object
#  7   Kullanım Durumu     1114 non-null   object
#  8   Kısıtlama           1114 non-null   object
#  9   Metre Karesi (Net)  1114 non-null   int64
#  10  Oda Sayısı          1114 non-null   int64
#  11  Price               1114 non-null   object
#  12  Site İçerisinde     1114 non-null   object
#  13  Takaslı             1114 non-null   object
#  14  İlan No             1114 non-null   object
# ...

# %%
df['Krediye Uygun'].value_counts()
# Out:
# Krediye Uygun
# Evet     930
# Hayır    175
# Name: count, dtype: int64

# %%
df['Kısıtlama'].value_counts()
# Out:
# Kısıtlama
# Yok       1096
# Diğer       16
# İpotek       2
# Name: count, dtype: int64

# %%
df['Price'] = df['Price'].str.replace("TL","")
df['Price'] = df['Price'].str.replace(".","")
df['Price'] = df['Price'].astype(int)

# %%
df['Metre Karesi (Net)'] = df['Metre Karesi (Net)']**2

# %%
df['Banyo Sayısı'] = df['Banyo Sayısı']**4

# %%
df['Oda Sayısı'] = df['Oda Sayısı']**3

# %%
df
# Out:
#       Banyo Sayısı  Bina Yaşı Bulunduğu Kat Eşyalı     Isıtma  Kat Sayısı  \
# 0                1         28             3  Hayır   Doğalgaz           3
# 1                1         23             0  Hayır   Doğalgaz           6
# 2                1          7             7  Hayır   Doğalgaz          12
# 3               16          4             5  Hayır   Doğalgaz           5
# 4                1         18             1  Hayır   Doğalgaz           5
# ...            ...        ...           ...    ...        ...         ...
# 1118             1         13             9  Hayır   Doğalgaz           9
# 1119            16          7             6  Hayır   Doğalgaz           8
# 1120            16          7             2  Hayır   Doğalgaz           5
# 1121            16         23             1  Hayır  Kalorifer           2
# 1122            16         28             1  Hayır   Doğalgaz           5
#
#      Krediye Uygun Kullanım Durumu Kısıtlama  Metre Karesi (Net)  Oda Sayısı  \
# ...

# %%
df['Bulunduğu Kat']=df['Bulunduğu Kat'].astype(int)

# %%
x=df.drop(['Price','İlan Türü','İlan Tarihi','İlan No'],axis=1)
y=df['Price']

# %%
x=x.drop(["Bulunduğu Kat","Takaslı","Eşyalı","Krediye Uygun"],axis=1)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1114 entries, 0 to 1122
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Banyo Sayısı        1114 non-null   int64
#  1   Bina Yaşı           1114 non-null   int64
#  2   Isıtma              1114 non-null   object
#  3   Kat Sayısı          1114 non-null   int64
#  4   Kullanım Durumu     1114 non-null   object
#  5   Kısıtlama           1114 non-null   object
#  6   Metre Karesi (Net)  1114 non-null   int64
#  7   Oda Sayısı          1114 non-null   int64
#  8   Site İçerisinde     1114 non-null   object
#  9   Şehir               1114 non-null   object
# dtypes: int64(5), object(5)
# memory usage: 95.7+ KB

# %%
x=pd.get_dummies(x)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",100)

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error


def algo_test(x,y):
        L=LinearRegression()
        R=Ridge()
        Lass=Lasso()
        E=ElasticNet()
        ETR=ExtraTreeRegressor()
        GBR=GradientBoostingRegressor()
        kn=KNeighborsRegressor()
        dt=DecisionTreeRegressor()
        xgb=XGBRegressor()
        ab=AdaBoostRegressor()
        rf=RandomForestRegressor()


        algos=[L,R,Lass,E,ETR,GBR,kn,dt,xgb,ab,rf]
        algo_names=['Linear','Ridge','Lasso','ElasticNet','Extra Tree','Gradient Boosting',
                    'KNeighbors','Decision Tree','XGBRegressor', 'AdaBoost', 'Random Forest']

        x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.2,random_state=42)

        r_squared= []
        rmse= []
        mae= []

        result=pd.DataFrame(columns=['R_Squared','RMSE','MAE'],index=algo_names)


        for algo in algos:
            p=algo.fit(x_train,y_train).predict(x_test)
            r_squared.append(r2_score(y_test,p))
            rmse.append(mean_squared_error(y_test,p)**.5)
            mae.append(mean_absolute_error(y_test,p))


        result.R_Squared=r_squared
        result.RMSE=rmse
        result.MAE=mae

        rtable=result.sort_values('R_Squared',ascending=False)
        return rtable

# %%
algo_test(x,y)
# Out:
#                    R_Squared          RMSE           MAE
# XGBRegressor        0.804001  4.158776e+06  1.890086e+06
# Gradient Boosting   0.774906  4.456778e+06  1.873012e+06
# Random Forest       0.665378  5.433958e+06  2.008922e+06
# Ridge               0.628089  5.728731e+06  2.395346e+06
# Lasso               0.626096  5.744062e+06  2.403135e+06
# Linear              0.626095  5.744067e+06  2.403141e+06
# ElasticNet          0.624469  5.756543e+06  2.341427e+06
# KNeighbors          0.490018  6.708362e+06  2.598206e+06
# Decision Tree       0.484131  6.746970e+06  2.647706e+06
# Extra Tree          0.436002  7.054684e+06  2.953367e+06
# AdaBoost            0.230011  8.242921e+06  5.547507e+06

# %% [markdown]
# ## Result

# %% [markdown]
# As a result, the data collected through web scraping was used for training and testing purposes in a regression model after necessary preprocessing. The R² score achieved with the XGBRegressor model was 80%.
